# %%
print("My name is Meghprit.")
print("My favourite app is Youtube.")
# Out:
# My name is Meghprit.
# My favourite app is Youtube.

# %%
print("Welcome to Data Science with Python!")
# Out:
# Welcome to Data Science with Python!
